# %% [markdown]
# # Prior Diagnosis Preprocessing (NEW DATA)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from datetime import datetime
import os
import glob

database_dir = r"D:\TriNetX\Diagnosis\\"   # Location where the database files are stored 
#working_dir = r"D:\TriNetX\Diagnosis\"
working_dir = r"C:\Users\reblo\Box\Residency Personal Files\Scholarly Work\Locke Research Projects\TriNetX Code\Hypercapnia TriNetX CSV Processing\Working\\" #location where to read and right from (faster = better if space allows)
print(working_dir)
# num_spreadsheets = 30
num_spreadsheets = 1273
# Out:
# C:\Users\reblo\Box\Residency Personal Files\Scholarly Work\Locke Research Projects\TriNetX Code\Hypercapnia TriNetX CSV Processing\Working\\

# %% [markdown]
# ### Reformatting of CSVs

# %%
# Adding new indexes; adding new column names; removing unneeded columns; reformatting column data types

columns = ["patient_id","encounter_id","code_system","code","principal_diagnosis_indicator","admitting_diagnosis","reason_for_visit","date","derived_by_TriNetX","source_id"]

for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(database_dir + "diagnosis"+f'{i:04}'+".csv",
                            names = columns,
                            dtype = {"patient_id":str,"encounter_id":str,"code":str},
                            parse_dates = ["date"])
    diagnosis.loc[diagnosis["principal_diagnosis_indicator"] == "Unknown", "principal_diagnosis_indicator"] = "U"  # Unknown, S U 
    diagnosis.loc[diagnosis["admitting_diagnosis"] == "Unknown", "admitting_diagnosis"] = "U" # F and U
    diagnosis.loc[diagnosis["reason_for_visit"] == "Unknown", "reason_for_visit"] = "U" # F and U
    diagnosis = diagnosis.drop(columns = ["code_system","derived_by_TriNetX","source_id"])
    diagnosis.to_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", index = False)
    print(diagnosis.shape)
    del diagnosis

#Test to ensure diagnosis indicators work
"""
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    test = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv")
    #display(test.head(10))

    print(test["principal_diagnosis_indicator"].value_counts())
    print(test["admitting_diagnosis"].value_counts())
    print(test["reason_for_visit"].value_counts())
    test.loc[test["principal_diagnosis_indicator"] == "Unknown", "principal_diagnosis_indicator"] = "U"
    test.loc[test["admitting_diagnosis"] == "Unknown", "admitting_diagnosis"] = "U"
    test.loc[test["reason_for_visit"] == "Unknown", "reason_for_visit"] = "U"

    display(test.head(10))
    print(test["principal_diagnosis_indicator"].value_counts())
    print(test["admitting_diagnosis"].value_counts())
    print(test["reason_for_visit"].value_counts())
"""

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Obstructive Sleep Apnea
# ### ICD-10: G47.3 – Obstructive Sleep Apnea (ADULT) (PEDIATRIC)

# %%
# G47.3: Obstructive Sleep Apnea
sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.match("^G47.3.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_G473 = pd.concat(sub_blocks, ignore_index = True)
HAS_G473.to_csv(working_dir +"HAS_G473.csv", index = False)
display(HAS_G473.head())
print("\n")
print(HAS_G473.shape)
print("\n")
print(HAS_G473["code"].value_counts())
# Out:
# 0001
# 0002
# 0003
# 0004
# 0005
# 0006
# 0007
# 0008
# 0009
# 0010
# 0011
# 0012
# 0013
# 0014
# 0015
# 0016
# 0017
# 0018
# 0019
# 0020
# 0021
# 0022
# 0023
# 0024
# 0025
# 0026
# 0027
# 0028
# 0029
# 0030
# 0031
# 0032
# 0033
# 0034
# 0035
# 0036
# 0037
# 0038
# 0039
# 0040
# 0041
# 0042
# 0043
# 0044
# 0045
# 0046
# 0047
# 0048
# 0049
# 0050
# 0051
# 0052
# 0053
# 0054
# 0055
# 0056
# 0057
# 0058
# 0059
# 0060
# 0061
# 0062
# 0063
# 0064
# 0065
# 0066
# 0067
# 0068
# 0069
# 0070
# 0071
# 0072
# 0073
# 0074
# 0075
# 0076
# 0077
# 0078
# 0079
# 0080
# 0081
# 0082
# 0083
# 0084
# 0085
# 0086
# 0087
# 0088
# 0089
# 0090
# 0091
# 0092
# 0093
# 0094
# 0095
# 0096
# 0097
# 0098
# 0099
# 0100
# 0101
# 0102
# 0103
# 0104
# 0105
# 0106
# 0107
# 0108
# 0109
# 0110
# 0111
# 0112
# 0113
# 0114
# 0115
# 0116
# 0117
# 0118
# 0119
# 0120
# 0121
# 0122
# 0123
# 0124
# 0125
# 0126
# 0127
# 0128
# 0129
# 0130
# 0131
# 0132
# 0133
# 0134
# 0135
# 0136
# 0137
# 0138
# 0139
# 0140
# 0141
# 0142
# ...

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Asthma
# ### ICD-10-CM: J45 - Asthma

# %%
# J45: Asthma

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^J45.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_J45 = pd.concat(sub_blocks, ignore_index = True)
HAS_J45.to_csv(working_dir +"HAS_J45.csv", index = False)
display(HAS_J45.head())
print("\n")
print(HAS_J45.shape)
print("\n")
print(HAS_J45["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # COPD
# ### ICD-10-CM: J43 - COPD (emphysema)

# %%
# ICD-10-CM: J43 - COPD (emphysema)

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^J43.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_J43 = pd.concat(sub_blocks, ignore_index = True)
HAS_J43.to_csv(working_dir +"HAS_J43.csv", index = False)
display(HAS_J43.head())
print("\n")
print(HAS_J43.shape)
print("\n")
print(HAS_J43["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # COPD
# ### ICD-10-CM: J44 - COPD (emphysema)

# %%
# ICD-10-CM: J44 - COPD (emphysema)

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^J44.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_J44 = pd.concat(sub_blocks, ignore_index = True)
HAS_J44.to_csv(working_dir +"HAS_J44.csv", index = False)
display(HAS_J44.head())
print("\n")
print(HAS_J44.shape)
print("\n")
print(HAS_J44["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Congestive Heart Failure
# ### ICD-10-CM: I50 - Congestive Heart Failure

# %%
# ICD-10-CM: I50 - Congestive Heart Failure

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^I50.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_I50 = pd.concat(sub_blocks, ignore_index = True)
HAS_I50.to_csv(working_dir +"HAS_I50.csv", index = False)
display(HAS_I50.head())
print("\n")
print(HAS_I50.shape)
print("\n")
print(HAS_I50["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Stroke - Cerebral infarction due to unspecified occlusion or stenosis of unspecified cerebral artery
# ### ICD-10-CM: I63 - Stroke

# %%
# ICD-10-CM: I63 - Stroke

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^I63.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_I63 = pd.concat(sub_blocks, ignore_index = True)
HAS_I63.to_csv(working_dir +"HAS_I63.csv", index = False)
display(HAS_I63.head())
print("\n")
print(HAS_I63.shape)
print("\n")
print(HAS_I63["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Chronic Kidney Disease
# ### ICD-10-CM: N18 - CKD

# %%
# ICD-10-CM: N18 - CKD

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^N18.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_N18 = pd.concat(sub_blocks, ignore_index = True)
HAS_N18.to_csv(working_dir +"HAS_N18.csv", index = False)
display(HAS_N18.head())
print("\n")
print(HAS_N18.shape)
print("\n")
print(HAS_N18["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Rheumatoid Arthritis - #1
# ### ICD-10-CM: M05 - Rheumatoid Arthritis

# %%
# ICD-10-CM: M05 - Rheumatoid Arthritis

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^M05.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_M05 = pd.concat(sub_blocks, ignore_index = True)
HAS_M05.to_csv(working_dir +"HAS_M05.csv", index = False)
display(HAS_M05.head())
print("\n")
print(HAS_M05.shape)
print("\n")
print(HAS_M05["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Rheumatoid Arthritis - #2
# ### ICD-10-CM: M06 Rheumatoid Arthritis

# %%
# ICD-10-CM: M06 Rheumatoid Arthritis

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^M06.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_M06 = pd.concat(sub_blocks, ignore_index = True)
HAS_M06.to_csv(working_dir +"HAS_M06.csv", index = False)
display(HAS_M06.head())
print("\n")
print(HAS_M06.shape)
print("\n")
print(HAS_M06["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Connective Tissue Disease - #1
# ### ICD-10-CM: M30 - Connective Tissue Disease

# %%
# ICD-10-CM: M30 - Connective Tissue Disease

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^M30.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_M30 = pd.concat(sub_blocks, ignore_index = True)
HAS_M30.to_csv(working_dir +"HAS_M30.csv", index = False)
display(HAS_M30.head())
print("\n")
print(HAS_M30.shape)
print("\n")
print(HAS_M30["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Connective Tissue Disease - #2
# ### ICD-10-CM: M31 - Connective Tissue Disease

# %%
# ICD-10-CM: M31 - Connective Tissue Disease

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^M31.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_M31 = pd.concat(sub_blocks, ignore_index = True)
HAS_M31.to_csv(working_dir +"HAS_M31.csv", index = False)
display(HAS_M31.head())
print("\n")
print(HAS_M31.shape)
print("\n")
print(HAS_M31["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Connective Tissue Disease - #3
# ### ICD-10-CM: M32 - Connective Tissue Disease

# %%
# ICD-10-CM: M32 - Connective Tissue Disease

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^M32.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_M32 = pd.concat(sub_blocks, ignore_index = True)
HAS_M32.to_csv(working_dir +"HAS_M32.csv", index = False)
display(HAS_M32.head())
print("\n")
print(HAS_M32.shape)
print("\n")
print(HAS_M32["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Connective Tissue Disease - #4
# ### ICD-10-CM: M33 - Connective Tissue Disease

# %%
# ICD-10-CM: M33 - Connective Tissue Disease

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^M33.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_M33 = pd.concat(sub_blocks, ignore_index = True)
HAS_M33.to_csv(working_dir +"HAS_M33.csv", index = False)
display(HAS_M33.head())
print("\n")
print(HAS_M33.shape)
print("\n")
print(HAS_M33["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Connective Tissue Disease - #5
# ### ICD-10-CM: M34 - Connective Tissue Disease

# %%
# ICD-10-CM: M34 - Connective Tissue Disease

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^M34.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_M34 = pd.concat(sub_blocks, ignore_index = True)
HAS_M34.to_csv(working_dir +"HAS_M34.csv", index = False)
display(HAS_M34.head())
print("\n")
print(HAS_M34.shape)
print("\n")
print(HAS_M34["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Connective Tissue Disease - #6
# ### ICD-10-CM: M35 - Connective Tissue Disease

# %%
# ICD-10-CM: M35 - Connective Tissue Disease

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^M35.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_M35 = pd.concat(sub_blocks, ignore_index = True)
HAS_M35.to_csv(working_dir +"HAS_M35.csv", index = False)
display(HAS_M35.head())
print("\n")
print(HAS_M35.shape)
print("\n")
print(HAS_M35["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Connective Tissue Disease - #7
# ### ICD-10-CM: M36 - Connective Tissue Disease

# %%
# ICD-10-CM: M36 - Connective Tissue Disease

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^M36.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_M36 = pd.concat(sub_blocks, ignore_index = True)
HAS_M36.to_csv(working_dir +"HAS_M36.csv", index = False)
display(HAS_M36.head())
print("\n")
print(HAS_M36.shape)
print("\n")
print(HAS_M36["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Dementia - #1
# ### ICD-10-CM: F01 - Dementia

# %%
### ICD-10-CM: F01 - Dementia

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^F01.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_F01 = pd.concat(sub_blocks, ignore_index = True)
HAS_F01.to_csv(working_dir +"HAS_F01.csv", index = False)
display(HAS_F01.head())
print("\n")
print(HAS_F01.shape)
print("\n")
print(HAS_F01["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Dementia - #2
# ### ICD-10-CM: F02 - Dementia

# %%
### ICD-10-CM: F02 - Dementia

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^F02.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_F02 = pd.concat(sub_blocks, ignore_index = True)
HAS_F02.to_csv(working_dir +"HAS_F02.csv", index = False)
display(HAS_F02.head())
print("\n")
print(HAS_F02.shape)
print("\n")
print(HAS_F02["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Dementia - #3
# ### ICD-10-CM: F03 - Dementia

# %%
### ICD-10-CM: F03 - Dementia

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^F03.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_F03 = pd.concat(sub_blocks, ignore_index = True)
HAS_F03.to_csv(working_dir +"HAS_F03.csv", index = False)
display(HAS_F03.head())
print("\n")
print(HAS_F03.shape)
print("\n")
print(HAS_F03["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Dementia - #4
# ### ICD-10-CM: F04 - Dementia

# %%
### ICD-10-CM: F04 - Dementia

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^F04.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_F04 = pd.concat(sub_blocks, ignore_index = True)
HAS_F04.to_csv(working_dir +"HAS_F04.csv", index = False)
display(HAS_F04.head())
print("\n")
print(HAS_F04.shape)
print("\n")
print(HAS_F04["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Dementia - #5
# ### ICD-10-CM: F05 - Dementia

# %%
### ICD-10-CM: F05 - Dementia

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^F05.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_F05 = pd.concat(sub_blocks, ignore_index = True)
HAS_F05.to_csv(working_dir +"HAS_F05.csv", index = False)
display(HAS_F05.head())
print("\n")
print(HAS_F05.shape)
print("\n")
print(HAS_F05["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Dementia - #6
# ### ICD-10-CM: F06 - Dementia

# %%
### ICD-10-CM: F06 - Dementia

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^F06.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_F06 = pd.concat(sub_blocks, ignore_index = True)
HAS_F06.to_csv(working_dir +"HAS_F06.csv", index = False)
display(HAS_F06.head())
print("\n")
print(HAS_F06.shape)
print("\n")
print(HAS_F06["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Dementia - #7
# ### ICD-10-CM: F07 - Dementia

# %%
### ICD-10-CM: F07 - Dementia

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^F07.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_F07 = pd.concat(sub_blocks, ignore_index = True)
HAS_F07.to_csv(working_dir +"HAS_F07.csv", index = False)
display(HAS_F07.head())
print("\n")
print(HAS_F07.shape)
print("\n")
print(HAS_F07["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Dementia - #8
# ### ICD-10-CM: F08 - Dementia

# %%
### ICD-10-CM: F08 - Dementia

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^F08.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_F08 = pd.concat(sub_blocks, ignore_index = True)
HAS_F08.to_csv(working_dir +"HAS_F08.csv", index = False)
display(HAS_F08.head())
print("\n")
print(HAS_F08.shape)
print("\n")
print(HAS_F08["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Dementia - #9
# ### ICD-10-CM: F09 - Dementia

# %%
### ICD-10-CM: F09 - Dementia

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^F09.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_F09 = pd.concat(sub_blocks, ignore_index = True)
HAS_F09.to_csv(working_dir +"HAS_F09.csv", index = False)
display(HAS_F09.head())
print("\n")
print(HAS_F09.shape)
print("\n")
print(HAS_F09["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Diabetes - #1
# ### ICD-10-CM: E08 - Diabetes

# %%
# ICD-10-CM: E08 - Diabetes

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^E08.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_E08 = pd.DataFrame()
HAS_E08 = pd.concat(sub_blocks, ignore_index = True)
HAS_E08.to_csv(working_dir +"HAS_E08.csv", index = False)
display(HAS_E08.head())
print("\n")
print(HAS_E08.shape)
print("\n")
print(HAS_E08["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Diabetes - #2
# ### ICD-10-CM: E09 - Diabetes

# %%
# ICD-10-CM: E09 - Diabetes

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^E09.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_E09 = pd.concat(sub_blocks, ignore_index = True)
HAS_E09.to_csv(working_dir +"HAS_E09.csv", index = False)
display(HAS_E09.head())
print("\n")
print(HAS_E09.shape)
print("\n")
print(HAS_E09["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Diabetes - #3
# ### ICD-10-CM: E10 - Diabetes

# %%
# ICD-10-CM: E10 - Diabetes

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^E10.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_E10 = pd.concat(sub_blocks, ignore_index = True)
HAS_E10.to_csv(working_dir +"HAS_E10.csv", index = False)
display(HAS_E10.head())
print("\n")
print(HAS_E10.shape)
print("\n")
print(HAS_E10["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Diabetes - #4
# ### ICD-10-CM: E11 - Diabetes

# %%
# ICD-10-CM: E11 - Diabetes

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^E11.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_E11 = pd.concat(sub_blocks, ignore_index = True)
HAS_E11.to_csv(working_dir +"HAS_E11.csv", index = False)
display(HAS_E11.head())
print("\n")
print(HAS_E11.shape)
print("\n")
print(HAS_E11["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Diabetes - #5
# ### ICD-10-CM: E12 - Diabetes

# %%
# ICD-10-CM: E12 - Diabetes

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^E12.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_E12 = pd.concat(sub_blocks, ignore_index = True)
HAS_E12.to_csv(working_dir +"HAS_E12.csv", index = False)
display(HAS_E12.head())
print("\n")
print(HAS_E12.shape)
print("\n")
print(HAS_E12["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Diabetes - #6
# ### ICD-10-CM: E13 - Diabetes

# %%
# ICD-10-CM: E13 - Diabetes

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^E13.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_E13 = pd.concat(sub_blocks, ignore_index = True)
HAS_E13.to_csv(working_dir +"HAS_E13.csv", index = False)
display(HAS_E13.head())
print("\n")
print(HAS_E13.shape)
print("\n")
print(HAS_E13["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Peripheral Vascular Diasease
# ### ICD-10-CM: I70 - Peripheral Vascular Diasease

# %%
# ICD-10-CM: I70 - Peripheral Vascular Diasease

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^I70.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_I70 = pd.concat(sub_blocks, ignore_index = True)
HAS_I70.to_csv(working_dir +"HAS_I70.csv", index = False)
display(HAS_I70.head())
print("\n")
print(HAS_I70.shape)
print("\n")
print(HAS_I70["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Opiate Use Disorder
# ### ICD-10-CM: F11 - Opiate Use Disorder

# %%
### ICD-10-CM: F11 - Opiate Use Disorder

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^F11.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_F11 = pd.concat(sub_blocks, ignore_index = True)
HAS_F11.to_csv(working_dir +"HAS_F11.csv", index = False)
display(HAS_F11.head())
print("\n")
print(HAS_F11.shape)
print("\n")
print(HAS_F11["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Sedative, Hypnotic, Anxiolytic Related Disorders
# ### ICD-10-CM: F13 - Sedative, hypnotic, anxiolytic related disorders

# %%
# ICD-10-CM: F13 - Sedative, hypnotic, anxiolytic related disorders

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^F13.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_F13 = pd.concat(sub_blocks, ignore_index = True)
HAS_F13.to_csv(working_dir +"HAS_F13.csv", index = False)
display(HAS_F13.head())
print("\n")
print(HAS_F13.shape)
print("\n")
print(HAS_F13["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Cystic Fibrosis
# ### ICD-10-CM: E84 - Cystic Fibrosis

# %%
### ICD-10-CM: E84 - Cystic Fibrosis

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^E84.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_E84 = pd.concat(sub_blocks, ignore_index = True)
HAS_E84.to_csv(working_dir +"HAS_E84.csv", index = False)
display(HAS_E84.head())
print("\n")
print(HAS_E84.shape)
print("\n")
print(HAS_E84["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Pulmonary Hypertension / Cor Pulmonale
# ### ICD-10-CM: I27 - Pulmonary Hypertension / Cor Pulmonale

# %%
### ICD-10-CM: I27 - Pulmonary Hypertension / Cor Pulmonale

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^I27.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_I27 = pd.concat(sub_blocks, ignore_index = True)
HAS_I27.to_csv(working_dir +"HAS_I27.csv", index = False)
display(HAS_I27.head())
print("\n")
print(HAS_I27.shape)
print("\n")
print(HAS_I27["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Secondary Polycythemia
# ### ICD-10-CM: D75.1 - Secondary Polycythemia

# %%
### ICD-10-CM: D75.1 - Secondary Polycythemia

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^D75.1.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_D751 = pd.concat(sub_blocks, ignore_index = True)
HAS_D751.to_csv(working_dir +"HAS_D751.csv", index = False)
display(HAS_D751.head())
print("\n")
print(HAS_D751.shape)
print("\n")
print(HAS_D751["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Amyotrophic lateral sclerosis (ALS) - #1
# ### ICD-10-CM: G12 - Amyotrophic lateral sclerosis (ALS)

# %%
# ICD-10-CM: G12 - Amyotrophic lateral sclerosis (ALS)

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^G12.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_G12 = pd.concat(sub_blocks, ignore_index = True)
HAS_G12.to_csv(working_dir +"HAS_G12.csv", index = False)
display(HAS_G12.head())
print("\n")
print(HAS_G12.shape)
print("\n")
print(HAS_G12["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Amyotrophic lateral sclerosis (ALS) - #2
# ### ICD-10-CM: G14 - Amyotrophic lateral sclerosis (ALS)

# %%
# ICD-10-CM: G14 - Amyotrophic lateral sclerosis (ALS)

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^G14.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_G14 = pd.concat(sub_blocks, ignore_index = True)
HAS_G14.to_csv(working_dir +"HAS_G14.csv", index = False)
display(HAS_G14.head())
print("\n")
print(HAS_G14.shape)
print("\n")
print(HAS_G14["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Myasthenia Gravis (MG) and Other Myoneural Disorders
# ### ICD-10-CM: G70 - Myasthenia Gravis (MG) and Other Myoneural Disorders

# %%
# ICD-10-CM: G70 - Myasthenia Gravis (MG) and Other Myoneural Disorders

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^G70.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_G70 = pd.concat(sub_blocks, ignore_index = True)
HAS_G70.to_csv(working_dir +"HAS_G70.csv", index = False)
display(HAS_G70.head())
print("\n")
print(HAS_G70.shape)
print("\n")
print(HAS_G70["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Multiple Sclerosis (MS)
# ### ICD-10-CM: G35 - Multiple Sclerosis (MS)

# %%
# ICD-10-CM: G35 - Multiple Sclerosis (MS)

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^G35.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_G35 = pd.concat(sub_blocks, ignore_index = True)
HAS_G35.to_csv(working_dir +"HAS_G35.csv", index = False)
display(HAS_G35.head())
print("\n")
print(HAS_G35.shape)
print("\n")
print(HAS_G35["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Muscular Dystrophy (including Duchenne/becker/myotonic)
# ### ICD-10-CM: G71 - Muscular Dystrophy (including Duchenne/becker/myotonic)

# %%
# ICD-10-CM: G71 - Muscular Dystrophy (including Duchenne/becker/myotonic)

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^G71.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_G71 = pd.concat(sub_blocks, ignore_index = True)
HAS_G71.to_csv(working_dir +"HAS_G71.csv", index = False)
display(HAS_G71.head())
print("\n")
print(HAS_G71.shape)
print("\n")
print(HAS_G71["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Spinal Cord Injury
# ### ICD-10-CM: G95 - Spinal Cord Injury

# %%
# ICD-10-CM: G95 - Spinal Cord Injury

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^G95.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_G95 = pd.concat(sub_blocks, ignore_index = True)
HAS_G95.to_csv(working_dir +"HAS_G95.csv", index = False)
display(HAS_G95.head())
print("\n")
print(HAS_G95.shape)
print("\n")
print(HAS_G95["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Other Demyelinating Conditions - #1
# ### ICD-10-CM: G36 - Other Demyelinating Conditions

# %%
# ICD-10-CM: G36 - Other Demyelinating Conditions

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^G36.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_G36 = pd.concat(sub_blocks, ignore_index = True)
HAS_G36.to_csv(working_dir +"HAS_G36.csv", index = False)
display(HAS_G36.head())
print("\n")
print(HAS_G36.shape)
print("\n")
print(HAS_G36["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Other Demyelinating Conditions - #2
# ### ICD-10-CM: G37 - Other Demyelinating Conditions

# %%
# ICD-10-CM: G37 - Other Demyelinating Conditions

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^G37.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_G37 = pd.concat(sub_blocks, ignore_index = True)
HAS_G37.to_csv(working_dir +"HAS_G37.csv", index = False)
display(HAS_G37.head())
print("\n")
print(HAS_G37.shape)
print("\n")
print(HAS_G37["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Nicotine, Inhalant, or Cannabis Related Disorders - #1
# ### ICD-10-CM: F17 - Nicotine, Inhalant, or Cannabis Related Disorders

# %%
# ICD-10-CM: F17 - Nicotine, Inhalant, or Cannabis Related Disorders

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^F17.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_F17 = pd.concat(sub_blocks, ignore_index = True)
HAS_F17.to_csv(working_dir +"HAS_F17.csv", index = False)
display(HAS_F17.head())
print("\n")
print(HAS_F17.shape)
print("\n")
print(HAS_F17["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Nicotine, Inhalant, or Cannabis Related Disorders - #2
# ### ICD-10-CM: F12 - Nicotine, Inhalant, or Cannabis Related Disorders

# %%
# ICD-10-CM: F12 - Nicotine, Inhalant, or Cannabis Related Disorders

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^F12.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_F12 = pd.concat(sub_blocks, ignore_index = True)
HAS_F12.to_csv(working_dir +"HAS_F12.csv", index = False)
display(HAS_F12.head())
print("\n")
print(HAS_F12.shape)
print("\n")
print(HAS_F12["code"].value_counts())

# %% [markdown]
# ### #############################################################################################

# %% [markdown]
# # Nicotine, Inhalant, or Cannabis Related Disorders - #3
# ### ICD-10-CM: F18 - Nicotine, Inhalant, or Cannabis Related Disorders

# %%
# ICD-10-CM: F18 - Nicotine, Inhalant, or Cannabis Related Disorders

sub_blocks = []
for i in range(1, num_spreadsheets+1):
    print(f'{i:04}')
    diagnosis = pd.read_csv(working_dir + "diagnosis_NEW_"+f'{i:04}'+".csv", 
        dtype={"patient_id":str, 
               "encounter_id":str, 
               "code":'category', 
               "principal_diagnosis_indicator":'category',
               "admitting_diagnosis":'category',
               "reason_for_visit":'category', 
               "date":'category'})
    diagnosis = diagnosis[diagnosis["code"].str.contains("^F18.*")]
    sub_blocks.append(diagnosis)
    del diagnosis

HAS_F18 = pd.concat(sub_blocks, ignore_index = True)
HAS_F18.to_csv(working_dir +"HAS_F18.csv", index = False)
display(HAS_F18.head())
print("\n")
print(HAS_F18.shape)
print("\n")
print(HAS_F18["code"].value_counts())

# %% [markdown]
# ### Clean Datasets Code
#
# Commented out so that the prior diagnosis can use the new splits for current

# %%
# Construct the pattern to match the files
# This pattern matches "encounter_" followed by exactly 4 digits and ".csv"
pattern = os.path.join(working_dir, "diagnosis_NEW_????"+".csv")

# Use glob.glob to find all files that match the pattern
matching_files = glob.glob(pattern)

# Iterate over the list of matching files and delete each one
for file_path in matching_files:
    try:
        #os.remove(file_path)
        print(f"Deleted file: {file_path}")
    except Exception as e:
        print(f"Error deleting file {file_path}: {e}")
